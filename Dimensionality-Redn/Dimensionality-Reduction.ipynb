# %%
# !pip install numpy pandas

# %%
import pandas as pd
path = './wine.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
import pandas as pd

# Define the column names as per dataset documentation
columns = [
    "Class", "Alcohol", "Malic_acid", "Ash", "Alcalinity_of_ash", "Magnesium",
    "Total_phenols", "Flavanoids", "Nonflavanoid_phenols", "Proanthocyanins",
    "Color_intensity", "Hue", "OD280/OD315", "Proline"
]

# Load the CSV file (replace 'wine.csv' with your actual file path if different)
df = pd.read_csv('wine.csv', header=None, names=columns)

# Show the first 5 rows to verify loading
print(df.head())
# Out:
#    Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  OD280/OD315  Proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# ...

# %%
df
# Out:
#      Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
print(df.isnull().sum())
# Out:
# Class                   0
# Alcohol                 0
# Malic_acid              0
# Ash                     0
# Alcalinity_of_ash       0
# Magnesium               0
# Total_phenols           0
# Flavanoids              0
# Nonflavanoid_phenols    0
# Proanthocyanins         0
# Color_intensity         0
# Hue                     0
# OD280/OD315             0
# Proline                 0
# dtype: int64

# %%
# !pip install StandardScaler
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.4 MB/s  0:00:00 eta 0:00:01
# ...
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# ...
#   Created wheel for StandardScaler: filename=standardscaler-0.5-py3-none-any.whl size=2649 sha256=63cad1fbb92934cb2188b471df6f7e08221ae8b4f334f51a89e798f538a54867
#   Stored in directory: /Users/ashna/Library/Caches/pip/wheels/2b/d1/60/2d36ac8038a442fd0a85ed1c771f2b13452cd79e267d5499dd
# Successfully built StandardScaler
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [StandardScaler]m [dask]]
# ...

# %%
from sklearn.preprocessing import StandardScaler
# Features and Labels
X = df.iloc[:, 1:]
y = df['Class']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
